# %% [markdown]
# <a href="https://colab.research.google.com/github/DarioMejia/DarioMejia.github.io/blob/main/Codigo%20calculo%20de%20momentos%20en%20una%20viga%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Se pide al usuario que ingrese el tipo de perfil que desea calcular 
print("Los perfiles disponibles son:")
print("1) w610x155 [Perfil W con peralte D=611mm,Grosor de alma Tw=12.70mm, ancho de ala BF=324.0mmde grosor, grosor de ala TF=19.0mm]")
#Si se puede, tratar de insertar la imagen del perfil w
print("2) c380x74  [Perfil C con peralte D=381mm,Grosor de alma Tw=18.20mm, ancho de ala BF=94.4mmde grosor, grosor de ala TF=16.50mm]")
#igual caso,tratar de colocar la imagen aquí del perfil c
print("Seleccione 1 para el perfil W o 2 para el perfil C")
perfil=int(input("Ingrese el tipo de perfil que desea analizar:"))


#Este es el proceso que se realiza cuando el perfil elegido es el W610x155
if perfil == 1: 
  Posicion_perfil=int(input("¿Se va a trabajar en posición x-x[ Opción 1] o y-y[ Opcion 2 ]?"))
  if Posicion_perfil ==1:#Este es el proceso cuando es el perfil w y ademas se trabaja en x-x
       #Ahora se procede a elegir el material
    I=1290e6
    print("Elegir el material que se va a utilizar:")
    print("Material-Módulo de elasticidad,E[Mpa]")
    T=[["(1) AISI 316L.Acero inoxidable",200000],["(2) Aluminio1060-H16",69000],["(3) Hierro ductil",120000]]
    print(T)
    modulo_elasticidad=int(input("Ingrese [1].[2].[3]"))
    if modulo_elasticidad ==1:
      print("modulo de elasticidad =1 [AISI 316L.Acero inoxidable]")
      e=200000
    else:
      if modulo_elasticidad ==2:
        print("modulo elasticidad =2 [Aluminio1060-H16]")
        e=69000
      else:
       if modulo_elasticidad ==3:
        print("modulo elasticidad =3 [Hierro ductil]")
        e=120000
       else:
          if modulo_elasticidad !=1 or modulo_elasticidad !=2 or modulo_elasticidad!=3:
            print(" Error de selección. Solo puede ser [(1) AISI 316L.Acero inoxidable,200000],[(2) Aluminio1060-H16,69000],[(3) Hierro ductil,120000]")

#Aqui se termina cuando se elije el perfil 1 con la posicion x-x y se elije un modulo de elasticidad 1, 2 o 3


  else:
    if Posicion_perfil ==2:#Este es el proceso cuando es el perfil w y ademas se trabaja en y-y
      I=108e6
      print("Elegir el material que se va a utilizar:")
      print("Material-Módulo de elasticidad,E[Mpa]")
      T=[["(1) AISI 316L.Acero inoxidable",200000],["(2) Aluminio1060-H16",69000],["(3) Hierro ductil",120000]]
      print(T)
      modulo_elasticidad=int(input("Ingrese [1].[2].[3]"))
      if modulo_elasticidad ==1:
        print("modulo de elasticidad =1 [AISI 316L.Acero inoxidable]")
        e=200000
      else:
       if modulo_elasticidad ==2:
        print("modulo elasticidad =2 [Aluminio1060-H16]")
        e=69000
       else:
        if modulo_elasticidad ==3:
          print("modulo elasticidad =3 [Hierro ductil]")
          e=120000
        else:
          if modulo_elasticidad !=1 or modulo_elasticidad !=2 or modulo_elasticidad!=3:
            print(" Error de selección. Solo puede ser [(1) AISI 316L.Acero inoxidable,200000],[(2) Aluminio1060-H16,69000],[(3) Hierro ductil,120000]")
  #Aqui se termina cuando se elije el perfil 1 con la posicion y-y,y se elije un modulo de elasticidad 1, 2 o 3

    else:
      if Posicion_perfil !=1 or Posicion_perfil !=2:
         print("El numero debe ser 1 o 2, por favor ingrese nuevamente")



else:#Este es el proceso que se realiza cuando el perfil elegido es el c380x74
   if perfil==2: 
    Posicion_perfil=int(input("¿Se va a trabajar en posición x-x[ Opción 1] o y-y[ Opcion 2 ]?"))
    if Posicion_perfil ==1: #Este es el proceso cuando es el perfil c y ademas se trabaja en x-x
      I=168e6
      #Ahora se procede a elegir el material
      print("Elegir el material que se va a utilizar:")
      print("Material-Módulo de elasticidad,E[Mpa]")
      T=[["(1) AISI 316L.Acero inoxidable",200000],["(2) Aluminio1060-H16",69000],["(3) Hierro ductil",120000]]
      print(T)
      modulo_elasticidad=int(input("Ingrese [1].[2].[3]"))
      if modulo_elasticidad ==1:
       print("modulo de elasticidad =1 [AISI 316L.Acero inoxidable]")
       e=200000
      else:
       if modulo_elasticidad ==2:
        print("modulo elasticidad =2 [Aluminio1060-H16]")
        e=69000
       else:
        if modulo_elasticidad ==3:
         print("modulo elasticidad =3 [Hierro ductil]")
         e=120000
        else:
          if modulo_elasticidad !=1 or modulo_elasticidad !=2 or modulo_elasticidad!=3:
            print(" Error de selección. Solo puede ser [(1) AISI 316L.Acero inoxidable,200000],[(2) Aluminio1060-H16,69000],[(3) Hierro ductil,120000]")
#Aqui se termina cuando se elije el perfil 2 con la posicion x-x y se elije un modulo de elasticidad 1, 2 o 3
    else:
      if Posicion_perfil ==2:#Este es el proceso cuando es el perfil c y ademas se trabaja en y-y
       I=4.58e6
       print("Elegir el material que se va a utilizar:")
       print("Material-Módulo de elasticidad,E[Mpa]")
       T=[["(1) AISI 316L.Acero inoxidable",200000],["(2) Aluminio1060-H16",69000],["(3) Hierro ductil",120000]]
       print(T)
       modulo_elasticidad=int(input("Ingrese [1].[2].[3]"))
       if modulo_elasticidad ==1:
        print("modulo de elasticidad =1 [AISI 316L.Acero inoxidable]")
        e=200000
       else:
        if modulo_elasticidad ==2:
         print("modulo elasticidad =2 [Aluminio1060-H16]")
         e=69000
        else:
         if modulo_elasticidad ==3:
          print("modulo elasticidad =3 [Hierro ductil]")
          e=120000
         else:
          if modulo_elasticidad !=1 or modulo_elasticidad !=2 or modulo_elasticidad!=3:
            print(" Error de selección. Solo puede ser [(1) AISI 316L.Acero inoxidable,200000],[(2) Aluminio1060-H16,69000],[(3) Hierro ductil,120000]")
#Aqui se termina cuando se elije el perfil 2 con la posicion y-y,y se elije un modulo de elasticidad 1, 2 o 3    
#Aqui va cuando el perfil elegido no es ni uno o dos 
   else:
    if perfil !=1 or perfil!=2:
      print("El numero debe ser 1 o 2, por favor ingrese nuevamente")

#####proceso grafica momento flector interno 
#Se crea una funcion que vaya  guardando los valores que va tomando la grafica a medida que se desarolla la funcion 
#Se tiene que insertar x, que son las diferentes distancias a las que se desea calcular el valor total del punto elástico
#Se tiene que insertar a, que es la distancia que hay desde el eje de apoyo hasta el punto de aplicación de la fuerza
#Se tiene que insertar L, Que es la longitud total de la vida 
#Se tiene que insertar p, que es el valor de la carga puntual 
l=float(input("Digite la longitud total de la viga[mm]")) #Los valores se pasan a metros para conservar la medida en newtons de la carga 
p=float(input("Digite el valor de la carga puntual [N]"))
a=float(input("Digite el valor de la distancia del punto de apoyo hasta la carga aplicada [mm]"))
x= int(input("Digite el valor de la distancia del punto de apoyo hasta la sección en donde se desea calcular el valor de la curva elástica en la viga [X][mm](Debe ser un numero entero)"))

import matplotlib.pyplot as plt
def m(x, a, p, l):#definir las variables sin asignarles x=0...etc puesto que son variables dentro de una funcion.
    if 0 <= x < a:
        return (1 - (a / l)) * p * x
    else:
      if a <= x <= l:
        return a * p * (1 - (x / l))
# Generar las matrices para los ejes x e yq
x_datos = []
y_datos = []
for x in range(int(l) + 1):
    x_datos.append(x)#se tuvo que  utilizar el comando append para agregar elementos al final de una lista existente, ..
    y_datos.append(m(x, a, p, l))#puesto que solo con ciclos no se conservaban los valores de la corrdenada y el grafico solo...
# arrojaba los numeros de los ejes sin las coordenadas.
# Graficar los valores
plt.plot(x_datos, y_datos)
plt.xlabel('Longitud viga')
plt.ylabel('Distribución de  carga')
plt.title('Distribución del momento flector interno')
plt.grid(True)
plt.show()

######Aqui se va a ingresar la grafica de la deflexion de la viga 
import matplotlib.pyplot as plt
import numpy as np


def m(x, a, p, l):
    if 0 <= x <= a:
        return (1 - (a / l) * p * x) / (e * I)
    elif a <= x <= l:
        return (a * p * (1 - (x / l))) / (e * I)

# Valores de x para graficar
x_vals = np.linspace(0, l, 100)  # Genera 100 puntos entre 0 y l

# Calcular y guardar los valores de y correspondientes
y_vals = [m(x, a, p, l) for x in x_vals]

# Graficar la función
plt.plot(x_vals, y_vals)
plt.xlabel('Longitud viga')
plt.ylabel('Distribución de la flexión ')
plt.title('Deflexion de la viga a lo largo de l')
plt.grid(True)
plt.show()
# Out:
# Los perfiles disponibles son:
# 1) w610x155 [Perfil W con peralte D=611mm,Grosor de alma Tw=12.70mm, ancho de ala BF=324.0mmde grosor, grosor de ala TF=19.0mm]
# 2) c380x74  [Perfil C con peralte D=381mm,Grosor de alma Tw=18.20mm, ancho de ala BF=94.4mmde grosor, grosor de ala TF=16.50mm]
# Seleccione 1 para el perfil W o 2 para el perfil C
# Ingrese el tipo de perfil que desea analizar:2
# ¿Se va a trabajar en posición x-x[ Opción 1] o y-y[ Opcion 2 ]?1
# Elegir el material que se va a utilizar:
# Material-Módulo de elasticidad,E[Mpa]
# [['(1) AISI 316L.Acero inoxidable', 200000], ['(2) Aluminio1060-H16', 69000], ['(3) Hierro ductil', 120000]]
# Ingrese [1].[2].[3]3
# modulo elasticidad =3 [Hierro ductil]
# Digite la longitud total de la viga[mm]100
# Digite el valor de la carga puntual [N]1500
# Digite el valor de la distancia del punto de apoyo hasta la carga aplicada [mm]50
# ...
